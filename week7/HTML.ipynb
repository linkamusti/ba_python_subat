# %%
# %%html
#
# <body>
# <h1>H1 Başlık</h1>
# <h2>H2 Başlık</h2>
# <h3>H3 Başlık</h3>
# <h4>H4 Başlık</h4>
# <h5>H5 Başlık</h5>
#
# <p>Bu benim paragrafım
# Birden fazla satır olabilir
# Epey bi yazı olabilir<br>
# Çok uzun şeyler bile yazabilirim
# Çekoslovakyalılaştıramadıklarımızdan mısınız?</p>
#
# <p>Aşağıda bir liste örneği yapacağız</p>
# <p>Sıra sayıları belli olan (ordered) listeler: </p>
#
# <ol>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
#     <li>Item 4</li>
#     <li>Item 5</li>
# </ol>
#
# <div style="display:flex; flex-direction:row; background-color:DodgerBlue; class="benim_divim">
#     <p>Sıra sayıları belirtilmeyen (unordered) listeler: </p>
#
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#         <li>Item 4</li>
#         <li>Item 5</li>
#     </ul>
# </div>
#
#
# <p>Form örneği:</p>
#
# <form>
#     <input type="text" placeholder="Adınızı girin">
#     <input type="text" placeholder="Soyadınızı girin">
#     <input type="password" placeholder="Şifrenizi">
#     <input type="date">
#     <input type="radio">
# </form>
#
#
# <p>Image örneği</p>
#
# <img src="https://fidansepetim.com/uploads/p/p/3-Yas-Asili-Granny-Smith-Elma-Fidani-Yesil-Mayhos_1.jpg">
#
#
# <p>Link Örneği</p>
# <a target="_blank" href="https://www.google.com">Bana Tıkla</a>
#
#
# <div>
#     <p>Ben Div İçerisindeyim</div>
# </div>
#
# <p>Ben Div İçerisinde Değilim</div>
#
# </body>
# Out:
# <body>
# <h1>H1 Başlık</h1>
# <h2>H2 Başlık</h2>
# <h3>H3 Başlık</h3>
# <h4>H4 Başlık</h4>
# <h5>H5 Başlık</h5>
#
# <p>Bu benim paragrafım
# Birden fazla satır olabilir
# Epey bi yazı olabilir<br>
# Çok uzun şeyler bile yazabilirim
# Çekoslovakyalılaştıramadıklarımızdan mısınız?</p>
#
# <p>Aşağıda bir liste örneği yapacağız</p>
# <p>Sıra sayıları belli olan (ordered) listeler: </p>
#
# <ol>
#     <li>Item 1</li>
#     <li>Item 2</li>
#     <li>Item 3</li>
#     <li>Item 4</li>
#     <li>Item 5</li>
# </ol>
#
# <div style="display:flex; flex-direction:row; background-color:DodgerBlue; class="benim_divim">
#     <p>Sıra sayıları belirtilmeyen (unordered) listeler: </p>
#
#     <ul>
#         <li>Item 1</li>
#         <li>Item 2</li>
#         <li>Item 3</li>
#         <li>Item 4</li>
#         <li>Item 5</li>
#     </ul>
# </div>
#
#
# <p>Form örneği:</p>
#
# <form>
#     <input type="text" placeholder="Adınızı girin">
#     <input type="text" placeholder="Soyadınızı girin">
# ...
