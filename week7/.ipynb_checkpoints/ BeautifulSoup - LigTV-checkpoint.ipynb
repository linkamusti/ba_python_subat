# %%
import requests
from bs4 import BeautifulSoup


url = "https://tr.beinsports.com/haberler"

response = requests.get(url)
html = response.text

soup = BeautifulSoup(html)

haberListesi = []


haberlerDiv = soup.find_all("div", {"class": "news_list"})[0]
simdikiHaber = haberlerDiv.div
haberIcerigi = simdikiHaber.find_all('div', {"class": "item_content"})[0].a.h2.string

haberListesi.append(haberIcerigi)
while True:
    try:
        simdikiHaber = simdikiHaber.findNextSibling()
       
        if simdikiHaber.get('class')[0] == "banner_middle":
            continue
        elif simdikiHaber.get('class')[0] == "news_item_small":
             print(simdikiHaber.div.a)
            print("-"*100)
            haberIcerigi = simdikiHaber.div.a.h2.string
            haberListesi.append(haberIcerigi)
        else:
            haberIcerigi = simdikiHaber.find_all('div', {"class": "item_content"})[0].a.h2.string
            haberListesi.append(haberIcerigi)

    except:
        break
# Out:
# <a href="/haber/bu-karsilasmalara-dikkat-4"><img alt="Bu karşılaşmalara dikkat" src="https://media04.ligtv.com.tr/img/news/2021/4/06/bu-karsilasmalara-dikkat-4/100_100/WEBBKD_connect.jpg"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="https://tr.beinsports.com/haftanin-golu" target="_blank"><img alt="Haftanın golünü siz seçin!" src="https://media05.ligtv.com.tr/img/news/2021/4/08/haftanin-golunu-siz-secin-92/100_100/ClearHaftanınGolü(1).jpg"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/iste-33-haftanin-savunma-ikilileri"><span class="spr video_news_all_news"></span><img alt="İşte 33. haftanın " savunma="" src="https://media05.ligtv.com.tr/img/news/2021/4/09/iste-33-haftanin-savunma-ikilileri/100_100/Castrol.png"/></a>
# ----------------------------------------------------------------------------------------------------
# None
# ----------------------------------------------------------------------------------------------------
# <a href="https://tr.beinsports.com/video-liste/en-guzel-kaybedenler" target="_blank"><img alt="İZLE | En güzel kaybedenler" src="https://media04.ligtv.com.tr/img/news/2021/4/08/izle-en-guzel-kaybedenler/100_100/panat(1).jpg"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/bolgesel-amator-lig-maclari-mayisa-ertelendi"><img alt="Bölgesel Amatör Lig maçları Mayıs'a ertelendi" src="https://media04.ligtv.com.tr/img/news/2021/4/09/bolgesel-amator-lig-maclari-mayisa-ertelendi/100_100/bal_9nisan.png"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/izmirde-maraton-zamani"><img alt="İzmir'de maraton zamanı" src="https://media05.ligtv.com.tr/img/news/2021/4/09/izmirde-maraton-zamani/100_100/izmir_9nisan.png"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/cengiz-underin-kaderi-belli-oldu"><img alt="Cengiz Ünder'in kaderi belli oldu" src="https://media06.ligtv.com.tr/img/news/2021/4/09/cengiz-underin-kaderi-belli-oldu/100_100/cengiz(1).jpg"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/trabzonspordan-nwakaeme-ve-ekuban-aciklamasi"><img alt="Trabzonspor'dan Nwakaeme ve Ekuban açıklaması" src="https://media05.ligtv.com.tr/img/news/2021/4/09/trabzonspordan-nwakaeme-ve-ekuban-aciklamasi/100_100/saglik_9nisan.png"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/u16-millilerin-aday-kadrosu-netlesti"><img alt="U16 Millilerin aday kadrosu netleşti" src="https://media04.ligtv.com.tr/img/news/2021/4/09/u16-millilerin-kamp-kadrosu-netlesti/100_100/milli_9nisan.png"/></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/baskan-cebiden-camiaya-birlik-cagrisi"><h2>Başkan Çebi'den camiaya birlik çağrısı<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/56-cumhurbaskanligi-bisiklet-turu-start-aliyor"><h2>56. Cumhurbaşkanlığı Bisiklet Turu start alıyor <span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/isimiz-bundan-sonra-basliyor"><h2>"İşimiz bundan sonra başlıyor"<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/a-hatayspor-mac-saatini-bekliyor"><h2>A. Hatayspor maç saatini bekliyor<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/el-clasico-zirveyi-sakillendirecek"><h2>El Clasico zirveyi şekillendirecek<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/edgar-lenin-ilginc-futbola-baslama-hikayesi"><h2>Edgar le'nin ilginç futbola başlama hikayesi<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/kasimpasa-hazirliklara-basladi"><h2>Kasımpaşa hazırlıklara başladı<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/fatih-karagumrukte-biglia-ve-borini-koronaviruse-yakalandi"><h2>Biglia ve Borini koronavirüse yakalandı<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/fenerbahcede-divan-kurulu-secimi-ertelendi"><h2>Fenerbahçe'de divan seçimsiz toplanacak<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="https://tr.beinsports.com/fotogaleri/cumhurbaskani-erdogan-cumhurbaskanligi-bisiklet-turu-ankara-kafilesini-kabul-etti" target="_blank"><h2>Cumhurbaşkanı Erdoğan, tur öncesinde kafileyi kabul etti<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/m-basaksehir-ara-vermedi"><h2>M. Başakşehir ara vermedi<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/dg-sivassporda-ih-konyaspor-mesaisi"><h2>DG Sivasspor'da İH Konyaspor mesaisi<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/goztepe-hatay-deplasmanina-hazir"><h2>Göztepe, Hatay deplasmanına hazır<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/gzt-giresunspor-54-yasinda"><h2>GZT Giresunspor 54 yaşında<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/y-samsunspor-seri-pesinde"><h2>Y. Samsunspor seri peşinde<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/haftanin-hakemleri-aciklandi-44"><h2>Haftanın hakemleri açıklandı<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/insallah-iki-takimimizi-da-final-fourda-goruruz"><h2>"İnşallah iki takımımızı da Final Four'da görürüz"<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
# <a href="/haber/bakan-kasapoglundan-onat-kazakliya-tebrik"><h2>Bakan Kasapoğlu'ndan Onat Kazaklı'ya tebrik<span class="comment">0</span></h2><span class="desc"> </span></a>
# ----------------------------------------------------------------------------------------------------
