# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys # Enter'a basmak için
import time
import random


chromedriver_path = "/Users/mustafakemaltas/Desktop/Bilge Adam Python 2/week7/"

class Instagram:
    def __init__(self):
        self.driver = webdriver.Chrome(executable_path=chromedriver_path+"chromedriver")
        
    def goToNextPhoto(self):
        nextArrow = self.driver.find_element_by_css_selector(".coreSpriteRightPaginationArrow")
        nextArrow.click()
        
    def takeScreenshot(self, fname):
        self.driver.save_screenshot(fname)
        
    def clickFirstPhoto(self):
        firstPhoto = self.driver.find_element_by_css_selector(".v1Nh3 a")
        firstPhoto.click()
        
    def login(self, username, password):
        self.driver.get("https://www.instagram.com/accounts/login/")
        time.sleep(2)
        usernameInput = self.driver.find_element_by_xpath("//input[@name='username']")
        passwordInput = self.driver.find_element_by_xpath("//input[@name='password']")

        usernameInput.send_keys(username)
        passwordInput.send_keys(password)
        passwordInput.send_keys(Keys.ENTER)
        
        
    def goToAccount(self, account):
        self.driver.get("https://www.instagram.com/{}".format(account))
        
        
        
username = "PYTHONOGRENIYOZ"
password = "pythonpython"
instagram = Instagram()

instagram.login(username, password)
time.sleep(5)
instagram.goToAccount("realbarbarapalvin")
time.sleep(3)
instagram.clickFirstPhoto()


counter = 0
while True:
    try:
        time.sleep(2)
        instagram.takeScreenshot("barbara{}.png".format(counter))
        instagram.goToNextPhoto()
        counter += 1
    except:
        break
print("BİTTİ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4f7919ee9760> in <module>
#      42 instagram = Instagram()
#      43
# ---> 44 instagram.login(username, password)
#      45 time.sleep(5)
#      46 instagram.goToAccount("realbarbarapalvin")
#
# <ipython-input-13-4f7919ee9760> in login(self, username, password)
#      23
#      24     def login(self, username, password):
# ---> 25         self.driver.get("https://www.instagram.com/accounts/login/")
#      26         time.sleep(2)
#      27         usernameInput = self.driver.find_element_by_xpath("//input[@name='username']")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      68                                            **urlopen_kw)
#      69         else:
# ---> 70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
#      72                                             **urlopen_kw)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:
