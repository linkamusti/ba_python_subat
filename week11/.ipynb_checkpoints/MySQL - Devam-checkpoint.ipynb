# %%
# MySQL Update

# MySQL Connection
import mysql.connector as connector

mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

sql_command = "UPDATE products SET price=15 WHERE name='su'"

mycursor.execute(sql_command)

try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
    
mydb.close()

# %%
#MySQL Update (parametric)

# MySQL Connection
import mysql.connector as connector

mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

sql_command = "UPDATE products SET description=%s WHERE name=%s"

parameters = ("içilmez", "su",)
mycursor.execute(sql_command, parameters)

try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
    
mydb.close()

# %%
# MySQL Delete Row(s)

# MySQL Connection
import mysql.connector as connector

mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

sql_command = "DELETE FROM products WHERE price >= 2000"

mycursor.execute(sql_command)

try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
    
mydb.close()

# %%
# MySQL Add a new column to table

# MySQL Connection
import mysql.connector as connector

mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

sql_command = "ALTER TABLE products ADD category_id VARCHAR(255);"

mycursor.execute(sql_command)

try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
    
mydb.close()

# %%
# MySQL Add a new column to table

# MySQL Connection
import mysql.connector as connector

mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

sql_command = "UPDATE products SET category_id=%s WHERE name=%s"


params = ("0", "armut")
mycursor.execute(sql_command, params)

try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
    
mydb.close()

# %%
# MySQL Connection
import mysql.connector as connector


mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

mycursor.execute("CREATE TABLE categories(name VARCHAR(255),id VARCHAR(255))")
try:
    mydb.commit()
except connector.Error as err:
    print('hata: ', err)
    
mydb.close()

# %%
mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

insert_sql = "INSERT INTO categories(name, id) VALUES(%s, %s)"

mycursor.execute(insert_sql, ("Yiyecek", "0"))
mycursor.execute(insert_sql, ("Temizlik", "1"))
mycursor.execute(insert_sql, ("Ev/Dekorasyon", "3"))
mycursor.execute(insert_sql, ("İçecek", "4"))
    
try:
    mydb.commit() # değişiklikler database'e yansıtılıyor.
    print("{} tane kayıt eklendi.".format(mycursor.rowcount))
    print("son eklenen kaydın id numarası: {}".format(mycursor.lastrowid))
except connector.Error as err:
    print("hata:", err)
    
    

mydb.close()
# Out:
# 1 tane kayıt eklendi.
# son eklenen kaydın id numarası: 0

# %%
mydb = connector.connect(
    host="db4free.net",
    user="bilgeadam",
    password="bilgeadam",
    database="bilgeadam_test")

mycursor = mydb.cursor() # create a cursor to use database

#sql_command = "SELECT * FROM products INNER JOIN categories ON categories.id = products.category_id"
sql_command = "SELECT products.name, price, categories.name FROM products INNER JOIN categories ON categories.id = products.category_id"

mycursor.execute(sql_command)

try:
    result = mycursor.fetchall()
    for r in result:
        print(r)
except connector.Error as err:
    print("hata:", err)
    
mydb.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-4f6f54b91451> in <module>
#      10 sql_command = "SELECT *.name FROM products INNER JOIN categories ON categories.id = products.category_id"
#      11
# ---> 12 mycursor.execute(sql_command)
#      13
#      14 try:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     649             query = query.encode('utf-8')
#     650         try:
# --> 651             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     652         except errors.ProgrammingError as err:
#     653             if err.errno == 3948 and \
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mysql/connector/connection.py in _handle_result(self, packet)
#     536             return self._handle_eof(packet)
#     537         elif packet[4] == 255:
# --> 538             raise errors.get_exception(packet)
#     539
#     540         # We have a text result set
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '.name FROM products INNER JOIN categories ON categories.id = products.category_i' at line 1
